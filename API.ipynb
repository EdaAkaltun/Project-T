# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
# x = 5.468132
# y = 52.547327
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "QUERY_LAYERS": "bodemdaling_2020_2050hoog",
    "LAYERS": "bodemdaling_2020_2050hoog",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Construct the URL using string formatting
url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
print(url)
# Send the request and parse the JSON response
response = requests.get(url)
data = response.json()

# Extract the "properties" field from the response
properties = data["features"][0]["properties"]

# Print the "properties" field
print(properties)
# Out:
# https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&SERVICE=WMS&VERSION=1.3.0&REQUEST=GetFeatureInfo&FORMAT=image/png&TRANSPARENT=true&QUERY_LAYERS=bodemdaling_2020_2050hoog&LAYERS=bodemdaling_2020_2050hoog&INFO_FORMAT=application/json&FEATURE_COUNT=8&I=50&J=50&CRS=EPSG:4326&STYLES=&WIDTH=101&HEIGHT=101&BBOX=51.873622,4.119859,51.873722,4.119959&x=4.119859&y=51.873622
# {'GRAY_INDEX': 0.03867279763858893}

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
# x = 5.468132
# y = 52.547327
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "QUERY_LAYERS": "overstromingsdiepte_extreem_kleine_kans",
    "LAYERS": "overstromingsdiepte_extreem_kleine_kans",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Construct the URL using string formatting
url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
print(url)
# Send the request and parse the JSON response
response = requests.get(url)
data = response.json()

# Extract the "properties" field from the response
properties = data["features"][0]["properties"]

# Print the "properties" field
print(properties)
number = properties['GRAY_INDEX']
# Out:
# https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&SERVICE=WMS&VERSION=1.3.0&REQUEST=GetFeatureInfo&FORMAT=image/png&TRANSPARENT=true&QUERY_LAYERS=overstromingsdiepte_extreem_kleine_kans&LAYERS=overstromingsdiepte_extreem_kleine_kans&INFO_FORMAT=application/json&FEATURE_COUNT=8&I=50&J=50&CRS=EPSG:4326&STYLES=&WIDTH=101&HEIGHT=101&BBOX=51.873622,4.119859,51.873722,4.119959&x=4.119859&y=51.873622
# {'GRAY_INDEX': 2.338599920272827}
# 2.338599920272827

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the common URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Define a list of layers to query
layers = ["overstromingsdiepte_extreem_kleine_kans", "overstromingsdiepte_kleine_kans", "overstromingsdiepte_middelgrote_kans", "overstromingsdiepte_grote_kans"]

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string formatting
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    print(data)

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Print the "properties" field
    print(f"Layer: {layer}, properties: {properties}")
    number = properties['GRAY_INDEX']

response_data = responses["overstromingsdiepte_extreem_kleine_kans"]
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': '', 'geometry': None, 'properties': {'GRAY_INDEX': 2.338599920272827}}], 'totalFeatures': 'unknown', 'numberReturned': 1, 'timeStamp': '2023-04-01T08:45:15.686Z', 'crs': None}
# Layer: overstromingsdiepte_extreem_kleine_kans, properties: {'GRAY_INDEX': 2.338599920272827}
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': '', 'geometry': None, 'properties': {'GRAY_INDEX': -9999}}], 'totalFeatures': 'unknown', 'numberReturned': 1, 'timeStamp': '2023-04-01T08:45:16.294Z', 'crs': None}
# Layer: overstromingsdiepte_kleine_kans, properties: {'GRAY_INDEX': -9999}
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': '', 'geometry': None, 'properties': {'GRAY_INDEX': -9999}}], 'totalFeatures': 'unknown', 'numberReturned': 1, 'timeStamp': '2023-04-01T08:45:16.847Z', 'crs': None}
# Layer: overstromingsdiepte_middelgrote_kans, properties: {'GRAY_INDEX': -9999}
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': '', 'geometry': None, 'properties': {'GRAY_INDEX': -9999}}], 'totalFeatures': 'unknown', 'numberReturned': 1, 'timeStamp': '2023-04-01T08:45:17.317Z', 'crs': None}
# Layer: overstromingsdiepte_grote_kans, properties: {'GRAY_INDEX': -9999}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 56
#      53     print(f"Layer: {layer}, properties: {properties}")
#      54     number = properties['GRAY_INDEX']
# ---> 56 response_data = responses["overstromingsdiepte_extreem_kleine_kans"]
#
# NameError: name 'responses' is not defined

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the common URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Define a dictionary to store the responses
responses = {}

# Define a list of layers to query
layers = ["overstromingsdiepte_extreem_kleine_kans", "overstromingsdiepte_kleine_kans", "overstromingsdiepte_middelgrote_kans", "overstromingsdiepte_grote_kans"]

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string formatting
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    
    # Store the response in the dictionary
    responses[layer] = data

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Print the "properties" field
    print(f"Layer: {layer}, properties: {properties}")
    number = properties['GRAY_INDEX']

response_data = responses["overstromingsdiepte_extreem_kleine_kans"]
# Out:
# Layer: overstromingsdiepte_extreem_kleine_kans, properties: {'GRAY_INDEX': 2.338599920272827}
# Layer: overstromingsdiepte_kleine_kans, properties: {'GRAY_INDEX': -9999}
# Layer: overstromingsdiepte_middelgrote_kans, properties: {'GRAY_INDEX': -9999}
# Layer: overstromingsdiepte_grote_kans, properties: {'GRAY_INDEX': -9999}

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the common URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Define a dictionary to store the responses
responses = {}

# Define a list of layers to query
layers = ["overstromingsdiepte_extreem_kleine_kans", "overstromingsdiepte_kleine_kans", "overstromingsdiepte_middelgrote_kans", "overstromingsdiepte_grote_kans"]

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string formatting
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    
    # Store the response in the dictionary
    responses[layer] = data

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Get the "GRAY_INDEX" value and check if it's -9999
    gray_index = properties['GRAY_INDEX']
    if gray_index == -9999:
        gray_index = 0
    
    # Print the "GRAY_INDEX" value
    print(f"Layer: {layer}, GRAY_INDEX: {gray_index}")

    extreem_kleine_kans = properties['GRAY_INDEX']


print(extreem_kleine_kans_gray_index)
# Out:
# Layer: overstromingsdiepte_extreem_kleine_kans, GRAY_INDEX: 2.338599920272827
# Layer: overstromingsdiepte_kleine_kans, GRAY_INDEX: 0
# Layer: overstromingsdiepte_middelgrote_kans, GRAY_INDEX: 0
# Layer: overstromingsdiepte_grote_kans, GRAY_INDEX: 0
# -9999

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the common URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Define a dictionary to store the responses
responses = {}

# Define a list of layers to query
layers = ["overstromingsdiepte_extreem_kleine_kans", "overstromingsdiepte_kleine_kans", "overstromingsdiepte_middelgrote_kans", "overstromingsdiepte_grote_kans"]

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string formatting
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    
    # Store the response in the dictionary
    responses[layer] = data

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Get the "GRAY_INDEX" value and replace it with 0 if it's -9999
    gray_index = properties['GRAY_INDEX']
    gray_index = 0 if gray_index == -9999 else gray_index
    
    # Print the "GRAY_INDEX" value
    print(f"Layer: {layer}, GRAY_INDEX: {gray_index}")
# Out:
# Layer: overstromingsdiepte_extreem_kleine_kans, GRAY_INDEX: 2.338599920272827
# Layer: overstromingsdiepte_kleine_kans, GRAY_INDEX: 0
# Layer: overstromingsdiepte_middelgrote_kans, GRAY_INDEX: 0
# Layer: overstromingsdiepte_grote_kans, GRAY_INDEX: 0

# %%
# Define the variables to store the numerical values
extreem_kleine_kans_val = 0
kleine_kans_val = 0
middelgrote_kans_val = 0
grote_kans_val = 0

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string formatting
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join(f"{k}={v}" for k, v in params.items())
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    
    # Store the response in the dictionary
    responses[layer] = data

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Get the "GRAY_INDEX" value and check if it's -9999
    gray_index = properties['GRAY_INDEX']
    if gray_index == -9999:
        gray_index = 0
    
    # Store the numerical value in the corresponding variable
    if layer == "overstromingsdiepte_extreem_kleine_kans":
        extreem_kleine_kans_val = properties['GRAY_INDEX']
    elif layer == "overstromingsdiepte_kleine_kans":
        kleine_kans_val = properties['GRAY_INDEX']
    elif layer == "overstromingsdiepte_middelgrote_kans":
        middelgrote_kans_val = properties['GRAY_INDEX']
    elif layer == "overstromingsdiepte_grote_kans":
        grote_kans_val = properties['GRAY_INDEX']

# Print the numerical values
print(f"extreem_kleine_kans_val: {extreem_kleine_kans_val}")
print(f"kleine_kans_val: {kleine_kans_val}")
print(f"middelgrote_kans_val: {middelgrote_kans_val}")
print(f"grote_kans_val: {grote_kans_val}")
# Out:
# extreem_kleine_kans_val: 2.338599920272827
# kleine_kans_val: -9999
# middelgrote_kans_val: -9999
# grote_kans_val: -9999

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the common URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Define a dictionary to store the responses
responses = {}

# Define a list of layers to query
layers = ["overstromingsdiepte_extreem_kleine_kans", "overstromingsdiepte_kleine_kans", "overstromingsdiepte_middelgrote_kans", "overstromingsdiepte_grote_kans"]

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string concatenation
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&"
    for k, v in params.items():
        url += f"{k}={v}&"
    url = url[:-1]
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    
    # Store the response in the dictionary
    responses[layer] = data

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Get the "GRAY_INDEX" value and check if it's -9999
    gray_index = properties['GRAY_INDEX']
    if gray_index == -9999:
        gray_index = 0
    
    # Print the "GRAY_INDEX" value
    print("Layer: " + layer + ", GRAY_INDEX: " + str(gray_index))

# Get the numerical value of overstromingsdiepte_grote_kans
grote_kans_num_value = responses["overstromingsdiepte_grote_kans"]["features"][0]["properties"]["GRAY_INDEX"]
if grote_kans_num_value == -9999:
    grote_kans_num_value = 0
    
print("Numerical value of overstromingsdiepte_grote_kans: " + str(grote_kans_num_value))
# Out:
# Layer: overstromingsdiepte_extreem_kleine_kans, GRAY_INDEX: 2.338599920272827
# Layer: overstromingsdiepte_kleine_kans, GRAY_INDEX: 0
# Layer: overstromingsdiepte_middelgrote_kans, GRAY_INDEX: 0
# Layer: overstromingsdiepte_grote_kans, GRAY_INDEX: 0
# Numerical value of overstromingsdiepte_grote_kans: 0

# %%
import requests

# Define the bounding box in EPSG:4326 (WGS84) coordinates as [min_lon, min_lat, max_lon, max_lat]
x = 4.119859
y = 51.873622
x1 = x + 0.0001
y1 = y + 0.0001
bbox = [y, x, y1, x1]

# Convert the bbox list to a string
bbox_str = ','.join(str(coord) for coord in bbox)

# Define the common URL parameters
params = {
    "SERVICE": "WMS",
    "VERSION": "1.3.0",
    "REQUEST": "GetFeatureInfo",
    "FORMAT": "image/png",
    "TRANSPARENT": "true",
    "INFO_FORMAT": "application/json",
    "FEATURE_COUNT": "8",
    "I": "50",
    "J": "50",
    "CRS": "EPSG:4326",
    "STYLES": "",
    "WIDTH": "101",
    "HEIGHT": "101",
    "BBOX": bbox_str,
    "x": x,
    "y": y,
}

# Define a dictionary to store the responses
responses = {}

# Define a list of layers to query
layers = ["overstromingsdiepte_extreem_kleine_kans", "overstromingsdiepte_kleine_kans", "overstromingsdiepte_middelgrote_kans", "overstromingsdiepte_grote_kans"]

# Loop over the layers and make separate requests for each layer
for layer in layers:
    params["QUERY_LAYERS"] = layer
    params["LAYERS"] = layer
    
    # Construct the URL using string formatting
    url = "https://apps.geodan.nl/public/data/org/gws/YWFMLMWERURF/kea_public/wms?v1_0&" + "&".join("{}={}".format(k, v) for k, v in params.items())
    
    # Send the request and parse the JSON response
    response = requests.get(url)
    data = response.json()
    
    # Store the response in the dictionary
    responses[layer] = data

    # Extract the "properties" field from the response
    properties = data["features"][0]["properties"]
    
    # Get the "GRAY_INDEX" value and check if it's -9999
    gray_index = properties['GRAY_INDEX']
    if gray_index == -9999:
        gray_index = 0
    
    # Store the numerical value in the corresponding variable
    if layer == "overstromingsdiepte_extreem_kleine_kans":
        extreem_kleine_kans_val = properties['GRAY_INDEX']
    elif layer == "overstromingsdiepte_kleine_kans":
        kleine_kans_val = properties['GRAY_INDEX']
    elif layer == "overstromingsdiepte_middelgrote_kans":
        middelgrote_kans_val = properties['GRAY_INDEX']
    elif layer == "overstromingsdiepte_grote_kans":
        grote_kans_val = properties['GRAY_INDEX']
# Out:
# extreem_kleine_kans_val: 2.338599920272827
# kleine_kans_val: -9999
# middelgrote_kans_val: -9999
# grote_kans_val: -9999

# %%
print(extreem_kleine_kans_val)
# Out:
# 2.338599920272827
