# %%
import matplotlib.pyplot as plt

# Equation
eqn = r'$y = 0.13\sqrt{x}$'

# Annotations
anno1 = r'$y$ = Relative Damage (factor)'
anno2 = r'$x$ = Water depth (m)'

# Plotting
plt.figure(figsize=(8, 6))
plt.text(0.5, 0.8, eqn, fontsize=20, ha='center')
plt.text(0.1, 0.7, anno1, fontsize=12, ha='left')
plt.text(0.1, 0.6, anno2, fontsize=12, ha='left')
plt.title('Vertical Displacement Calculation')
plt.axis('off')
plt.show()
